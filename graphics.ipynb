# %%
for i in range(1, 10000):
    if i < 10:
        x='000'+str(i)
    elif i < 100:
        x='00'+str(i)
    elif i < 1000:
        x='0'+str(i)
    else:
        x=str(i)
    print(f'\\u{x}')
# Out:
# 0001 \u0001
# 0002 \u0002
# 0003 \u0003
# 0004 \u0004
# 0005 \u0005
# 0006 \u0006
# 0007 \u0007
# 0008 \u0008
# 0009 \u0009
# 0010 \u0010
# 0011 \u0011
# 0012 \u0012
# 0013 \u0013
# 0014 \u0014
# 0015 \u0015
# 0016 \u0016
# 0017 \u0017
# 0018 \u0018
# 0019 \u0019
# 0020 \u0020
# 0021 \u0021
# 0022 \u0022
# 0023 \u0023
# 0024 \u0024
# 0025 \u0025
# 0026 \u0026
# 0027 \u0027
# 0028 \u0028
# 0029 \u0029
# 0030 \u0030
# 0031 \u0031
# 0032 \u0032
# 0033 \u0033
# 0034 \u0034
# 0035 \u0035
# 0036 \u0036
# 0037 \u0037
# 0038 \u0038
# 0039 \u0039
# 0040 \u0040
# 0041 \u0041
# 0042 \u0042
# 0043 \u0043
# 0044 \u0044
# 0045 \u0045
# 0046 \u0046
# 0047 \u0047
# 0048 \u0048
# 0049 \u0049
# 0050 \u0050
# 0051 \u0051
# 0052 \u0052
# 0053 \u0053
# 0054 \u0054
# 0055 \u0055
# 0056 \u0056
# 0057 \u0057
# 0058 \u0058
# 0059 \u0059
# 0060 \u0060
# 0061 \u0061
# 0062 \u0062
# 0063 \u0063
# 0064 \u0064
# 0065 \u0065
# 0066 \u0066
# 0067 \u0067
# 0068 \u0068
# 0069 \u0069
# 0070 \u0070
# 0071 \u0071
# ...
